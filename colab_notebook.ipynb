# %% [markdown]
# # `CATEGORÍA 1`

# %% [markdown]
# - ### `problema: #1` - Multiples of 3 or 5
# - enlace: https://projecteuler.net/problem=1

# %%
import problemas.categoria_1.problema_001 as problema_001
import time

comienza = time.time()
problema_001.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# la suma de todos los multiplos de 3 o 5 menores que 1000 es: 233168
#
# tiempo de ejecucion: 0.0010480881 segundos

# %% [markdown]
# - ### `problema: #2` - Even Fibonacci Numbers
# - enlace: https://projecteuler.net/problem=2

# %%
import problemas.categoria_1.problema_002 as p2
import time

comienza = time.time()
p2.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# La suma de los terminos pares de Fibonacci menores que 4000000 es: 4613732
#
# tiempo de ejecucion: 0.0005161762 segundos

# %% [markdown]
# - ### `problema: #3` - Largest Prime Factor
# - enlace: https://projecteuler.net/problem=3

# %%
import problemas.categoria_1.problema_003 as p3
import time

comienza = time.time()
p3.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# el mayor factor primo de 6000851475143 es: 6857
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #4` - Largest Palindrome Product
# - enlace: https://projecteuler.net/problem=4

# %%
import problemas.categoria_1.problema_004 as p4
import time

comienza = time.time()
p4.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# 906609 = 993 x 913
#
# tiempo de ejecucion: 0.0025134087 segundos

# %% [markdown]
# - ### `problema: #5` - Smallest Multiple
# - enlace: https://projecteuler.net/problem=5

# %%
import problemas.categoria_1.problema_005 as p5
import time

comienza = time.time()
p5.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# el numero mas pequenio divisible por todos los numeros del 1 al 20 es: 232792560
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #6` - Sum Square Difference
# - enlace: https://projecteuler.net/problem=6

# %%
import problemas.categoria_1.problema_006 as p6
import time

comienza = time.time()
p6.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# para los primeros 100 numeros naturales:
# suma de cuadrados: 338350
# cuadrado de la suma: 25502500
# diferencia: 25164150
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #7` - 10001st Prime
# - enlace: https://projecteuler.net/problem=7

# %%
import problemas.categoria_1.problema_007 as p7
import time

comienza = time.time()
p7.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# el numero 10001_ primo es: 104743
#
# tiempo de ejecucion: 0.0123612881 segundos

# %% [markdown]
# - ### `problema: #9` - Special Pythagorean Triplet
# - enlace: https://projecteuler.net/problem=9

# %%
import problemas.categoria_1.problema_009 as p9
import time

comienza = time.time()
p9.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# valores de la tripleta: a=200, b=375, c=425
# producto abc: 31875000
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #10` - Summation of Primes
# - enlace: https://projecteuler.net/problem=10

# %%
import problemas.categoria_1.problema_010 as p10
import time

comienza = time.time()
p10.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# La suma de los terminos pares de Fibonacci menores que 4000000 es: 4613732
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #12` - Highly Divisible Triangular Number
# - enlace: https://projecteuler.net/problem=12

# %%
import problemas.categoria_1.problema_012 as p12
import time

comienza = time.time()
p12.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# Triangular - T(12375) = 76576500 tiene 576 divisores
#
# tiempo de ejecucion: 2.8898856640 segundos

# %% [markdown]
# - ### `problema: #14` - Longest Collatz Sequence
# - enlace: https://projecteuler.net/problem=14

# %%
import problemas.categoria_1.problema_014 as p14
import time

comienza = time.time()
p14.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# calculo (hasta 1000000): 837799, longitud: 525
#
# tiempo de ejecucion: 10.7955272198 segundos

# %% [markdown]
# - ### `problema: #16` - Power Digit Sum
# - enlace: https://projecteuler.net/problem=16

# %%
import problemas.categoria_1.problema_016 as p16
import time

comienza = time.time()
p16.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# suma de digitos: 1366
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #17` - Number Letter Counts
# - enlace: https://projecteuler.net/problem=17

# %%
import problemas.categoria_1.problema_017 as p17
import time

comienza = time.time()
p17.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# total de letras para numeros del 1 al 1000: 21124
#
# tiempo de ejecucion: 0.0010058880 segundos

# %% [markdown]
# - ### `problema: #20` - Factorial Digit Sum
# - enlace: https://projecteuler.net/problem=20

# %%
import problemas.categoria_1.problema_020 as p20
import time

comienza = time.time()
p20.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# 100! tiene 158 digitos
# suma de digitos: 648
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #25` - 1000-digit Fibonacci Number
# - enlace: https://projecteuler.net/problem=25

# %%
import problemas.categoria_1.problema_025 as p25
import time

comienza = time.time()
p25.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# el primer numero de fibonacci con 1000 digitos es F(4782)
# F(4782) tiene 1000 ddgitos
#
# tiempo de ejecucion: 0.0283188820 segundos

# %% [markdown]
# - ### `problema: #28` - Number Spiral Diagonals
# - enlace: https://projecteuler.net/problem=28

# %%
import problemas.categoria_1.problema_028 as p28
import time

comienza = time.time()
p28.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# suma de diagonales en espiral 1001 x 1001: 669171001
#
# tiempo de ejecucion: 0.0000000000 segundos

# %% [markdown]
# - ### `problema: #30` - Digit Fifth Powers
# - enlace: https://projecteuler.net/problem=30

# %%
import problemas.categoria_1.problema_030 as p30
import time

comienza = time.time()
p30.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# numeros encontrados: [4150, 4151, 54748, 92727, 93084, 194979]
# suma total: 443839
#
# tiempo de ejecucion: 0.4062600136 segundos

# %% [markdown]
# - ### `problema: #34` - Digit Factorials
# - enlace: https://projecteuler.net/problem=34

# %%
import problemas.categoria_1.problema_034 as p34
import time

comienza = time.time()
p34.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# numeros encontrados: [145, 40585]
# suma total: 40730
#
# tiempo de ejecucion: 3.2841453552 segundos

# %% [markdown]
# - ### `problema: #35` - Circular Primes
# - enlace: https://projecteuler.net/problem=35

# %%
import problemas.categoria_1.problema_035 as p35
import time

comienza = time.time()
p35.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# primos circulares encontrados: 55
# ejemplos: [2, 3, 5, 7, 11, 13, 17, 31, 37, 71, 73, 79, 97, 113, 131, 197, 199, 311, 337, 373]...
#
# tiempo de ejecucion: 0.1837921143 segundos

# %% [markdown]
# - ### `problema: #36` - Double-base Palindromes
# - enlace: https://projecteuler.net/problem=36

# %%
import problemas.categoria_1.problema_036 as p36
import time

comienza = time.time()
p36.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# numeros encontrados: [1, 3, 5, 7, 9, 33, 99, 313, 585, 717, 7447, 9009, 15351, 32223, 39993, 53235, 53835, 73737, 585585]
# suma total: 872187
#
# tiempo de ejecucion: 0.1806666851 segundos

# %% [markdown]
# # `CATEGORÍA 2`

# %% [markdown]
# - ### `problema: #37` - Truncatable Primes
# - enlace: https://projecteuler.net/problem=37

# %%
import problemas.categoria_2.problema_037 as p37
import time

comienza = time.time()
p37.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# primos truncables encontrados: [23, 37, 53, 73, 313, 317, 373, 797, 3137, 3797, 739397]
# cantidad: 11
# suma total: 748317
#
# tiempo de ejecucion: 0.1189274788 segundos

# %% [markdown]
# - ### `problema: #41` - Pandigital Prime
# - enlace: https://projecteuler.net/problem=41

# %%
import problemas.categoria_2.problema_041 as p41
import time

comienza = time.time()
p41.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# el primo pandigital mas grande es: 7652413
# tiene 7 digitos
#
# tiempo de ejecucion: 0.0025556087 segundos

# %% [markdown]
# # `CATEGORÍA 3`

# %% [markdown]
# - ### `problema: #31` - Coin Sums
# - enlace: https://projecteuler.net/problem=31

# %%
import problemas.categoria_3.problema_031 as p31
import time

comienza = time.time()
p31.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# formas de formar 200 peniques: 73682
#
# tiempo de ejecucion: 0.0015659332 segundos

# %% [markdown]
# - ### `problema: #39` - Integer Right Triangles
# - enlace: https://projecteuler.net/problem=39

# %%
import problemas.categoria_3.problema_039 as p39
import time

comienza = time.time()
p39.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# Perímetro con máximo soluciones: p = 840
# Número de soluciones: 8
#
# tiempo de ejecucion: 0.0363960266 segundos

# %% [markdown]
# # `CATEGORÍA 4`

# %% [markdown]
# - ### `problema: # 146` - Investigating a Prime Pattern
# enlace: https://projecteuler.net/problem=146

# %%
import problemas.categoria_4.problema_146 as p146
import time

comienza = time.time()
p146.solve()
termina = time.time()
    
print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
# Out:
# encontrado n = 10 (total encontrados: 1)
# encontrado n = 315410 (total encontrados: 2)
# encontrado n = 927070 (total encontrados: 3)
# encontrado n = 2525870 (total encontrados: 4)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       2 import time
#       4 comienza = time.time()
# ----> 5 p146.solve()
#       6 termina = time.time()
#       8 print(f"\ntiempo de ejecucion: {termina - comienza:.10f} segundos")
#
# File c:\Users\~root\Desktop\6semestre\algoritmos\proyecto\proyecto_euler_algoritmos\problemas\categoria_4\problema_146.py:58, in solve()
#      56 #notemos que n debe ser múltiplo de 10, esto es por lo visto en el ejemplo n=10
#      57 for n in range(10, limite, 10):
# ---> 58     if vericador_patron(n):
#      59         suma_total += n
#      60         contador += 1
#
# ...
